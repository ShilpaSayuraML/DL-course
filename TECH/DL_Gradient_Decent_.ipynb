# %% [markdown]
# # # Gradient Descent : Linear Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.rand(100, 1)

# Add a bias term (intercept) to X
X_b = np.c_[np.ones((100, 1)), X]

# Initialize model parameters
theta = np.random.randn(2, 1)

# Set hyperparameters
learning_rate = 0.1
n_iterations = 1000

# Gradient Descent
for iteration in range(n_iterations):
    gradients = -2 / 100 * X_b.T.dot(y - X_b.dot(theta))
    theta -= learning_rate * gradients

# Print the learned parameters (theta)
print("Learned Parameters:")
print("Intercept (theta_0):", theta[0][0])
print("Slope (theta_1):", theta[1][0])

# Plot the data and regression line
plt.scatter(X, y)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Gradient Descent Linear Regression")
plt.plot(X, X_b.dot(theta), color='red')
plt.show()
# Out:
# Learned Parameters:
# Intercept (theta_0): 4.558080024157032
# Slope (theta_1): 2.968275530101875

# %%
y
# Out:
# array([[ 7.97069756],
#        [ 8.56114417],
#        [ 8.35177428],
#        [ 8.23148764],
#        [ 6.79068194],
#        [ 8.45152201],
#        [ 7.2175652 ],
#        [ 9.92288991],
#        [10.0050582 ],
#        [ 7.25339812],
#        [ 9.19747561],
#        [ 8.01977819],
#        [ 8.10774664],
#        [ 9.85101678],
#        [ 5.24001417],
#        [ 4.91928154],
#        [ 5.00241358],
#        [ 9.57699195],
#        [ 9.55067587],
#        [ 9.91260448],
#        [10.59696433],
#        [ 9.29627577],
#        [ 7.72495981],
#        [ 9.32716526],
#        [ 5.1335016 ],
#        [ 8.44591934],
#        [ 4.87931292],
#        [ 9.96958832],
#        [ 7.79126347],
#        [ 6.77804925],
#        [ 6.2053491 ],
#        [ 9.07417084],
#        [ 6.87237606],
#        [ 7.70888602],
#        [ 4.68270371],
#        [ 8.29668574],
#        [ 8.24689959],
#        [ 8.3548048 ],
#        [10.31459174],
#        [ 8.52234023],
#        [ 7.053594  ],
#        [ 6.98975359],
#        [ 8.6216521 ],
#        [ 5.25327618],
#        [ 8.80679428],
#        [ 8.7277158 ],
#        [ 5.36252225],
#        [ 5.6930404 ],
#        [ 6.60681141],
#        [ 7.18111163],
#        [ 7.57062893],
#        [ 7.49973514],
#        [10.09273596],
#        [ 5.22782843],
#        [ 5.37708052],
#        [ 5.81586534],
#        [ 8.72596891],
#        [ 6.08885035],
#        [ 7.20504793],
#        [ 5.53572055],
#        [ 5.65124628],
#        [ 5.11579353],
#        [ 8.66003314],
#        [ 5.69548003],
#        [ 6.15501568],
#        [ 7.06815437],
#        [ 8.93767346],
#        [ 4.94258572],
#        [ 9.75766001],
#        [ 4.74822012],
#        [10.3797934 ],
#        [ 6.8662452 ],
#        [10.06056305],
#        [ 7.64759491],
#        [ 9.22927918],
#        [ 4.45905144],
#        [ 6.04219346],
#        [ 5.64926066],
#        [ 6.48125559],
#        [ 4.74420524],
#        [ 6.07259323],
#        [ 7.10705637],
#        [ 4.96211357],
#        [ 8.39272554],
#        [ 8.33382272],
#        [ 6.2063029 ],
#        [ 7.67512112],
#        [ 5.15355304],
#        [ 8.185801  ],
#        [ 9.88772218],
#        [ 6.30963478],
#        [ 8.21430603],
#        [ 4.97698018],
#        [ 9.24233561],
#        [ 6.47598735],
#        [ 5.58960698],
#        [ 7.74649224],
#        [ 4.37500176],
#        [ 9.03166934],
#        [ 4.46258948]])

# %% [markdown]
# ## Gradient Decent: Logistics Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data
np.random.seed(0)
X = np.random.rand(100, 2)  # 100 samples with 2 features
y = (X[:, 0] + X[:, 1] > 1).astype(int)  # Binary classification

# Add a bias term to X
X_bias = np.c_[np.ones((X.shape[0], 1)), X]

# Logistic sigmoid function
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Initialize model parameters (weights)
theta = np.random.rand(3)

# Set hyperparameters
learning_rate = 0.01
epochs = 100

# Gradient Descent
for epoch in range(epochs):
    # Calculate the predicted probabilities
    logits = np.dot(X_bias, theta)
    y_pred = sigmoid(logits)

    # Calculate the gradient of the loss function (log-likelihood) w.r.t. parameters
    gradient = np.dot(X_bias.T, (y - y_pred))
    print(gradient )
    # Update parameters using Gradient Descent
    theta += learning_rate * gradient

# Now, theta contains the learned parameters for the logistic regression model
print("Learned Parameters (theta):", theta)

# Plot the decision boundary
plt.scatter(X[:, 0], X[:, 1], c=y)
x_boundary = np.linspace(0, 1.2, 100)
y_boundary = (-theta[0] - theta[1] * x_boundary) / theta[2]
plt.plot(x_boundary, y_boundary, color='red')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Logistic Regression Decision Boundary")
plt.show()
# Out:
# [-17.93656603  -3.66251983  -0.27146227]
# [-13.64229388  -1.4714102    1.77856896]
# [-10.56159166   0.0984435    3.21960205]
# [-8.46093279  1.15777482  4.16677426]
# [-7.06410109  1.84713772  4.75900606]
# [-6.14339668  2.285066    5.11151315]
# [-5.53498062  2.55777785  5.30741269]
# [-5.12812582  2.72388483  5.40294097]
# [-4.85032011  2.82189852  5.43493649]
# [-4.65486286  2.87666952  5.42711758]
# [-4.51194891  2.90407492  5.39460927]
# [-4.40264938  2.91420356  5.34700413]
# [-4.31497263  2.91344809  5.29036659]
# [-4.24132916  2.90585414  5.22852306]
# [-4.17691527  2.89398154  5.16388426]
# [-4.11868776  2.87945086  5.09796665]
# [-4.06471554  2.86328915  5.03172195]
# [-4.01377011  2.84614837  4.96574516]
# [-3.96506703  2.82844318  4.90040573]
# [-3.91810278  2.81043795  4.83593041]
# [-3.8725517   2.79230175  4.77245548]
# [-3.82820086  2.77414306  4.71005982]
# [-3.78490885  2.75603177  4.64878581]
# [-3.74257977  2.7380131   4.58865256]
# [-3.70114665  2.72011642  4.5296644 ]
# [-3.66056099  2.70236091  4.47181616]
# [-3.62078611  2.68475912  4.41509667]
# [-3.58179293  2.66731928  4.35949089]
# [-3.54355728  2.65004672  4.30498137]
# [-3.50605819  2.63294487  4.25154917]
# [-3.46927681  2.61601584  4.19917441]
# [-3.43319574  2.59926084  4.1478367 ]
# [-3.39779853  2.58268042  4.09751541]
# [-3.3630695   2.56627464  4.04818982]
# [-3.32899348  2.55004323  3.99983924]
# [-3.29555574  2.53398561  3.95244314]
# [-3.26274193  2.518101    3.90598113]
# [-3.23053801  2.50238845  3.8604331 ]
# [-3.19893026  2.48684682  3.81577915]
# [-3.16790522  2.47147489  3.77199971]
# [-3.13744974  2.4562713   3.72907548]
# [-3.10755091  2.44123462  3.6869875 ]
# [-3.07819611  2.42636333  3.64571712]
# [-3.04937296  2.41165585  3.60524604]
# [-3.02106938  2.39711053  3.5655563 ]
# [-2.99327352  2.38272568  3.52663026]
# [-2.96597381  2.36849956  3.48845068]
# [-2.93915894  2.35443042  3.45100061]
# [-2.91281783  2.34051645  3.4142635 ]
# [-2.8869397   2.32675582  3.37822313]
# [-2.86151398  2.3131467   3.34286362]
# [-2.83653037  2.29968723  3.30816944]
# [-2.8119788   2.28637556  3.27412543]
# [-2.78784947  2.27320981  3.24071673]
# [-2.76413279  2.2601881   3.20792885]
# [-2.74081941  2.24730857  3.17574761]
# [-2.71790021  2.23456935  3.14415918]
# [-2.69536631  2.22196857  3.11315003]
# [-2.67320902  2.20950438  3.08270697]
# [-2.6514199   2.19717494  3.0528171 ]
# [-2.6299907   2.18497841  3.02346786]
# [-2.60891338  2.17291296  2.99464697]
# [-2.58818011  2.16097681  2.96634245]
# [-2.56778325  2.14916816  2.93854261]
# [-2.54771537  2.13748523  2.91123605]
# [-2.5279692   2.12592628  2.88441165]
# [-2.50853768  2.11448956  2.85805856]
# [-2.48941393  2.10317337  2.83216619]
# [-2.47059122  2.09197601  2.80672423]
# [-2.45206301  2.08089581  2.78172261]
# [-2.43382293  2.06993112  2.75715151]
# [-2.41586477  2.05908031  2.73300137]
# [-2.39818247  2.04834176  2.70926285]
# [-2.38077013  2.0377139   2.68592685]
# [-2.363622    2.02719516  2.66298449]
# [-2.34673247  2.016784    2.64042713]
# [-2.33009609  2.0064789   2.61824633]
# [-2.31370753  1.99627838  2.59643386]
# [-2.2975616   1.98618094  2.57498169]
# [-2.28165324  1.97618516  2.55388202]
# [-2.26597753  1.9662896   2.53312721]
# [-2.25052966  1.95649285  2.51270983]
# [-2.23530494  1.94679353  2.49262262]
# [-2.22029881  1.93719028  2.47285852]
# [-2.20550681  1.92768177  2.45341062]
# [-2.19092459  1.91826667  2.43427221]
# [-2.17654794  1.90894369  2.41543673]
# [-2.16237271  1.89971156  2.39689778]
# [-2.14839488  1.89056902  2.37864913]
# [-2.13461051  1.88151484  2.36068468]
# [-2.12101579  1.87254781  2.34299852]
# [-2.10760698  1.86366673  2.32558483]
# [-2.09438041  1.85487043  2.30843799]
# [-2.08133255  1.84615776  2.29155248]
# [-2.06845992  1.83752759  2.27492293]
# [-2.05575913  1.8289788   2.25854409]
# [-2.04322687  1.82051029  2.24241085]
# [-2.03085993  1.81212099  2.22651822]
# [-2.01865515  1.80380984  2.21086131]
# [-2.00660946  1.79557579  2.19543539]
# Learned Parameters (theta): [-3.13719959  2.87737581  3.84310584]

# %% [markdown]
# ## Gredient Decent

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# Generate moon-shaped data
X, y = make_moons(n_samples=1000, noise=0.1)

# Visualize the data
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)
plt.title('Generated Moon-Shaped Data')
plt.show()

# %%
import tensorflow as tf
from tensorflow import keras

# Generate some synthetic data for demonstration
# Split the data into train and test sets
split_ratio = 0.8
split_index = int(len(X) * split_ratio)

x_train, x_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Build a simple feedforward neural network
model = keras.Sequential([
    keras.layers.Dense(32, activation='relu', input_dim=2),  # Input layer with ReLU activation
    keras.layers.Dense(16, activation='relu'),             # Hidden layer with ReLU activation
    keras.layers.Dense(1, activation='sigmoid')            # Output layer with Sigmoid activation (for binary classification)
])

# Compile the model
model.compile(optimizer='sgd',  # Stochastic Gradient Descent
              loss='binary_crossentropy',  # Binary cross-entropy loss for binary classification
              metrics=['accuracy'])

# Train the model using Batch Gradient Descent
history = model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 11ms/step - loss: 0.7069 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.5050
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6797 - accuracy: 0.5150 - val_loss: 0.6685 - val_accuracy: 0.4600
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6576 - accuracy: 0.6350 - val_loss: 0.6470 - val_accuracy: 0.7250
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6378 - accuracy: 0.8300 - val_loss: 0.6272 - val_accuracy: 0.8300
# Epoch 5/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6193 - accuracy: 0.8438 - val_loss: 0.6083 - val_accuracy: 0.8350
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6020 - accuracy: 0.8475 - val_loss: 0.5910 - val_accuracy: 0.8350
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5861 - accuracy: 0.8487 - val_loss: 0.5750 - val_accuracy: 0.8350
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5709 - accuracy: 0.8525 - val_loss: 0.5592 - val_accuracy: 0.8350
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5558 - accuracy: 0.8525 - val_loss: 0.5437 - val_accuracy: 0.8400
# Epoch 10/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.5409 - accuracy: 0.8525 - val_loss: 0.5284 - val_accuracy: 0.8400
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5264 - accuracy: 0.8525 - val_loss: 0.5133 - val_accuracy: 0.8400
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5120 - accuracy: 0.8512 - val_loss: 0.4985 - val_accuracy: 0.8400
# Epoch 13/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.8512 - val_loss: 0.4841 - val_accuracy: 0.8400
# Epoch 14/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4843 - accuracy: 0.8550 - val_loss: 0.4701 - val_accuracy: 0.8400
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.8562 - val_loss: 0.4565 - val_accuracy: 0.8400
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.8562 - val_loss: 0.4434 - val_accuracy: 0.8350
# Epoch 17/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4459 - accuracy: 0.8575 - val_loss: 0.4310 - val_accuracy: 0.8350
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.8550 - val_loss: 0.4191 - val_accuracy: 0.8400
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.8562 - val_loss: 0.4080 - val_accuracy: 0.8400
# Epoch 20/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4124 - accuracy: 0.8512 - val_loss: 0.3974 - val_accuracy: 0.8400
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4024 - accuracy: 0.8500 - val_loss: 0.3874 - val_accuracy: 0.8400
# Epoch 22/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8500 - val_loss: 0.3780 - val_accuracy: 0.8350
# Epoch 23/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3840 - accuracy: 0.8500 - val_loss: 0.3691 - val_accuracy: 0.8350
# Epoch 24/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3756 - accuracy: 0.8525 - val_loss: 0.3609 - val_accuracy: 0.8350
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3676 - accuracy: 0.8525 - val_loss: 0.3531 - val_accuracy: 0.8350
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3602 - accuracy: 0.8550 - val_loss: 0.3459 - val_accuracy: 0.8350
# Epoch 27/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.8537 - val_loss: 0.3391 - val_accuracy: 0.8400
# Epoch 28/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3466 - accuracy: 0.8550 - val_loss: 0.3328 - val_accuracy: 0.8400
# Epoch 29/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3404 - accuracy: 0.8562 - val_loss: 0.3269 - val_accuracy: 0.8500
# Epoch 30/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8587 - val_loss: 0.3214 - val_accuracy: 0.8600
# Epoch 31/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3289 - accuracy: 0.8600 - val_loss: 0.3162 - val_accuracy: 0.8600
# Epoch 32/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3237 - accuracy: 0.8612 - val_loss: 0.3113 - val_accuracy: 0.8650
# Epoch 33/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3188 - accuracy: 0.8625 - val_loss: 0.3068 - val_accuracy: 0.8650
# Epoch 34/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3140 - accuracy: 0.8637 - val_loss: 0.3025 - val_accuracy: 0.8700
# Epoch 35/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3097 - accuracy: 0.8625 - val_loss: 0.2984 - val_accuracy: 0.8700
# Epoch 36/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3054 - accuracy: 0.8650 - val_loss: 0.2946 - val_accuracy: 0.8700
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3015 - accuracy: 0.8650 - val_loss: 0.2910 - val_accuracy: 0.8750
# Epoch 38/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.8662 - val_loss: 0.2876 - val_accuracy: 0.8750
# Epoch 39/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2941 - accuracy: 0.8675 - val_loss: 0.2844 - val_accuracy: 0.8750
# Epoch 40/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2907 - accuracy: 0.8675 - val_loss: 0.2813 - val_accuracy: 0.8750
# Epoch 41/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2874 - accuracy: 0.8687 - val_loss: 0.2784 - val_accuracy: 0.8750
# Epoch 42/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2846 - accuracy: 0.8712 - val_loss: 0.2757 - val_accuracy: 0.8800
# Epoch 43/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.8725 - val_loss: 0.2730 - val_accuracy: 0.8800
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2787 - accuracy: 0.8712 - val_loss: 0.2705 - val_accuracy: 0.8850
# Epoch 45/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2759 - accuracy: 0.8763 - val_loss: 0.2682 - val_accuracy: 0.8900
# Epoch 46/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2735 - accuracy: 0.8775 - val_loss: 0.2659 - val_accuracy: 0.8900
# Epoch 47/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2710 - accuracy: 0.8750 - val_loss: 0.2637 - val_accuracy: 0.8900
# Epoch 48/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2687 - accuracy: 0.8788 - val_loss: 0.2617 - val_accuracy: 0.8950
# Epoch 49/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2664 - accuracy: 0.8838 - val_loss: 0.2597 - val_accuracy: 0.8950
# Epoch 50/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.8838 - val_loss: 0.2578 - val_accuracy: 0.8950
# Epoch 51/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2624 - accuracy: 0.8888 - val_loss: 0.2560 - val_accuracy: 0.8950
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2605 - accuracy: 0.8863 - val_loss: 0.2542 - val_accuracy: 0.8950
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2585 - accuracy: 0.8913 - val_loss: 0.2526 - val_accuracy: 0.8950
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2569 - accuracy: 0.8925 - val_loss: 0.2510 - val_accuracy: 0.8950
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2552 - accuracy: 0.8925 - val_loss: 0.2497 - val_accuracy: 0.8950
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2535 - accuracy: 0.8938 - val_loss: 0.2482 - val_accuracy: 0.8950
# Epoch 57/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2520 - accuracy: 0.8963 - val_loss: 0.2469 - val_accuracy: 0.8950
# Epoch 58/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2507 - accuracy: 0.8950 - val_loss: 0.2456 - val_accuracy: 0.8950
# Epoch 59/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.8950 - val_loss: 0.2444 - val_accuracy: 0.8950
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2479 - accuracy: 0.8963 - val_loss: 0.2431 - val_accuracy: 0.8950
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2467 - accuracy: 0.8950 - val_loss: 0.2421 - val_accuracy: 0.8950
# Epoch 62/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.8950 - val_loss: 0.2410 - val_accuracy: 0.8950
# Epoch 63/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2442 - accuracy: 0.8950 - val_loss: 0.2401 - val_accuracy: 0.8950
# Epoch 64/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2431 - accuracy: 0.8950 - val_loss: 0.2392 - val_accuracy: 0.8950
# Epoch 65/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2420 - accuracy: 0.8963 - val_loss: 0.2382 - val_accuracy: 0.8950
# Epoch 66/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2409 - accuracy: 0.8975 - val_loss: 0.2373 - val_accuracy: 0.8950
# Epoch 67/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2404 - accuracy: 0.8950 - val_loss: 0.2362 - val_accuracy: 0.8950
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2391 - accuracy: 0.8938 - val_loss: 0.2355 - val_accuracy: 0.8950
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2381 - accuracy: 0.8925 - val_loss: 0.2349 - val_accuracy: 0.8950
# Epoch 70/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.8963 - val_loss: 0.2339 - val_accuracy: 0.8950
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2364 - accuracy: 0.8963 - val_loss: 0.2333 - val_accuracy: 0.8950
# Epoch 72/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.8950 - val_loss: 0.2326 - val_accuracy: 0.8950
# Epoch 73/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2349 - accuracy: 0.8938 - val_loss: 0.2316 - val_accuracy: 0.8950
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.8938 - val_loss: 0.2310 - val_accuracy: 0.8950
# Epoch 75/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2335 - accuracy: 0.8938 - val_loss: 0.2304 - val_accuracy: 0.8950
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2331 - accuracy: 0.8950 - val_loss: 0.2299 - val_accuracy: 0.8950
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2320 - accuracy: 0.8963 - val_loss: 0.2291 - val_accuracy: 0.8950
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2313 - accuracy: 0.8963 - val_loss: 0.2285 - val_accuracy: 0.8950
# Epoch 79/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2307 - accuracy: 0.8950 - val_loss: 0.2281 - val_accuracy: 0.8950
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2304 - accuracy: 0.8963 - val_loss: 0.2274 - val_accuracy: 0.8950
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2296 - accuracy: 0.8975 - val_loss: 0.2269 - val_accuracy: 0.8950
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2290 - accuracy: 0.8988 - val_loss: 0.2261 - val_accuracy: 0.8950
# Epoch 83/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.8950 - val_loss: 0.2254 - val_accuracy: 0.9000
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2280 - accuracy: 0.8963 - val_loss: 0.2253 - val_accuracy: 0.8950
# Epoch 85/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2275 - accuracy: 0.8975 - val_loss: 0.2246 - val_accuracy: 0.8950
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2267 - accuracy: 0.8988 - val_loss: 0.2242 - val_accuracy: 0.8950
# Epoch 87/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2264 - accuracy: 0.8963 - val_loss: 0.2234 - val_accuracy: 0.8950
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.8975 - val_loss: 0.2229 - val_accuracy: 0.8900
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2256 - accuracy: 0.9000 - val_loss: 0.2226 - val_accuracy: 0.8950
# Epoch 90/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2249 - accuracy: 0.9000 - val_loss: 0.2223 - val_accuracy: 0.9000
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2247 - accuracy: 0.8963 - val_loss: 0.2217 - val_accuracy: 0.9000
# Epoch 92/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2242 - accuracy: 0.8963 - val_loss: 0.2211 - val_accuracy: 0.8950
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2236 - accuracy: 0.9013 - val_loss: 0.2207 - val_accuracy: 0.9000
# Epoch 94/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2232 - accuracy: 0.8988 - val_loss: 0.2204 - val_accuracy: 0.9000
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2227 - accuracy: 0.9000 - val_loss: 0.2199 - val_accuracy: 0.9000
# Epoch 96/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2222 - accuracy: 0.9013 - val_loss: 0.2193 - val_accuracy: 0.8950
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2218 - accuracy: 0.8963 - val_loss: 0.2192 - val_accuracy: 0.9000
# Epoch 98/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2214 - accuracy: 0.8988 - val_loss: 0.2187 - val_accuracy: 0.9000
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2212 - accuracy: 0.9013 - val_loss: 0.2181 - val_accuracy: 0.8950
# Epoch 100/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2210 - accuracy: 0.8988 - val_loss: 0.2176 - val_accuracy: 0.8950
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2176 - accuracy: 0.8950
# Test Loss: 0.21764762699604034, Test Accuracy: 0.8949999809265137

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
