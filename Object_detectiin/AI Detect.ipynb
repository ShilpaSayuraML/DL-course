# %%
text='Al-Garadi et. al  [1]  provides an ovierview of IoT systems. The author highlight security problems in encryption, authentication, access  various studies using to ML and DL  for addressing IoT security, and discuss challenges, opportunities, and future research directions on perception, network and  application layers of IoT. They discuss the integration with enabling technologies like edge computing and blockchain. The authors emphasizes the need for addressing quality of data issues. They raise ethical and privacy concerns specially in hethcare and home IoT applications of ML and DL. The authors bring attention to poisoning, evasion, impersonation attacks on ML and DL models, empherthize frequent monitoring, and security model updates in a dynamically changing IoT threat landscape.  While the paper reviews ML and DL methods comprehensivly on IoT security, it lacks focus on the real-world ML and DL deployment use cases, scalability of models, tranferbility and the operational aspects of maintaining in distributed IoT environments. Providing such insights could help bridge this gap.'

# %%
text='''
Otoum Y. and Nayak A. [4] explore the effectiveness of DL architectures in IoT security. They discuss IoT security requirements, the role of DL, and reviews number of research using DL approaches. They describe and  comparatively analyze on CNN. RNN, LSTM, DBN, and A E DL algorithms to identify several research issues for IoT security. These NN performance is evaluated using cross-validation. The authors found that DL outperforms shallow learning for attack detection. They stress the need for optimal features for attack detection. Considering emerging SDN and fog-enabled IoT, they state that IoT architectures should ensure quality of service without compromising security.
The paper has a weakness in specifying datasets used for several research, as the datasets are foundation of any research. It pinpoint the significant in parameter tuning in dense random networks, and  acknowledges the potential of DL in detecting cyber-attacks in distributed IoT environments. Lastly, the authors see DL-based Blockchain technologies as a promising direction for IoT security, to provide distributed security with data integrity.
'''

# %%
text
# Out:
# '\nOtoum Y. and Nayak A. [4] explore the effectiveness of DL architectures in IoT security. They discuss IoT security requirements, the role of DL, and reviews number of research using DL approaches. They describe and  comparatively analyze on CNN. RNN, LSTM, DBN, and A E DL algorithms to identify several research issues for IoT security. These NN performance is evaluated using cross-validation. The authors found that DL outperforms shallow learning for attack detection. They stress the need for optimal features for attack detection. Considering emerging SDN and fog-enabled IoT, they state that IoT architectures should ensure quality of service without compromising security.\nThe paper has a weakness in specifying datasets used for several research, as the datasets are foundation of any research. It pinpoint the significant in parameter tuning in dense random networks, and  acknowledges the potential of DL in detecting cyber-attacks in distributed IoT environments. Lastly, the author
# ...

# %%
import nltk
import matplotlib.pyplot as plt

# Download NLTK data (if not already downloaded)
nltk.download('punkt')

def visualize_word_per_sentence_distribution(text):
    # Tokenize the text into sentences and then words
    sentences = nltk.sent_tokenize(text)
    words_per_sentence = [len(nltk.word_tokenize(sentence)) for sentence in sentences]

    # Create a histogram to visualize the distribution
    plt.figure(figsize=(8, 6))
    plt.hist(words_per_sentence, bins=20, edgecolor='k', alpha=0.7)
    plt.xlabel('Number of Words per Sentence')
    plt.ylabel('Frequency')
    plt.title('Word per Sentence Distribution')
    plt.grid(True)
    plt.show()

# Example usage
sample_text = "This is a sample sentence. It contains several words. The words need to be counted."
visualize_word_per_sentence_distribution(text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt

# Download the stopwords dataset if not already downloaded
nltk.download("stopwords")

# Sample text
#text = """Your sample text goes here. Replace this with your actual text. You can load text from a file as well."""
nw=20
# Tokenize the text
words = nltk.word_tokenize(text)

# Filter out stop words
stop_words = set(stopwords.words("english"))
filtered_words = [word.lower() for word in words if word.lower() not in stop_words and word.isalnum()]

# Count word frequencies
word_freq = Counter(filtered_words)

# Get the top 20 words by frequency
top_words = word_freq.most_common(nw)

# Extract words and their frequencies for plotting
words, frequencies = zip(*top_words)

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(words, frequencies)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Word Frequencies (Excluding Stop Words)')
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
